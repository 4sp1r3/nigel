# %%
# %matplotlib inline
from custom import draw
from pythagoras import *
set_creator()

# %%
pop, logbook = run(get_toolbox(get_pset()))
# Out:
# gen	nevals	avg    	std   	max        	min
# 0  	100   	20426.6	158129	1.49246e+06	3
# 1  	91    	60171.6	356122	3.96291e+06	1
# 2  	91    	96566  	503181	4.83762e+06	1
# 3  	96    	92270.1	529441	4.83762e+06	1
# 4  	94    	117966 	599857	4.83762e+06	1
# 5  	87    	175073 	710257	4.83762e+06	1
# 6  	91    	145336 	624969	3.96591e+06	1
# 7  	96    	134000 	624618	4.25622e+06	1
# 8  	90    	162561 	728725	4.25622e+06	1
# 9  	86    	143220 	702089	4.40058e+06	1
# 10 	96    	158217 	769262	5e+06      	1
# 11 	96    	212334 	855589	5e+06      	1
# 12 	87    	207296 	797469	4.40058e+06	1
# 13 	94    	177396 	724604	4.96554e+06	1
# 14 	92    	173015 	715293	4.40058e+06	1
# 15 	89    	224985 	871033	4.40058e+06	1
# 16 	91    	173847 	740225	4.40058e+06	1
# 17 	84    	197002 	786731	4.40058e+06	1
# 18 	91    	207055 	812053	5e+06      	1
# 19 	94    	198656 	810535	5e+06      	1
# 20 	98    	262143 	908351	5e+06      	1
# 21 	96    	219880 	837715	5e+06      	1
# ...

# %%
for i in pop[:20]:
    print(i.fitness)
# Out:
# (0.0, 6.0)
# (0.0, 24.0)
# (0.0, 62.0)
# (403.2196285144659, 17.0)
# (224.10305368752233, 6.0)
# (5820.045039936248, 4.0)
# (715.5098892791824, 7.0)
# (1066.0683898888, 19.0)
# (246.5324049308451, 10.0)
# (249.9549600637519, 4.0)
# (249.9549600637519, 7.0)
# (249.9549600637519, 7.0)
# (265.95496006375197, 2.0)
# (1195176.2753752554, 8.0)
# (152.54257944998403, 6.0)
# (395.3605259560068, 9.0)
# (404.44926830573627, 13.0)
# (461.9935121911359, 9.0)
# (514.5457150338988, 14.0)
# (538.0322412797763, 9.0)

# %%
draw(pop[0])

# %%
str(pop[0])
# Out:
# 'sqrt(plus(square(getx(P)), minus(square(gety(P)), plus(sqrt(0), minus(0, sqrt(0))))))'
