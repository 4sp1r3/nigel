# %% [markdown]
# 5-Parity Problem with two ADFs, that don't know about each other, of 2 arguments each.

# %%
# %matplotlib inline
from app.madffiveparity import main
from app.ourMods import adfdraw

pop, stats, hof = main(gens=200, pop_size=300)
print(hof[0].fitness)
adfdraw(hof[0])
# Out:
# gen	avg   	std     	min   	max
# 0  	16.049	0.264822	15.024	18.032
# 1  	16.0462	0.246151	15.02 	17.052
# 2  	16.0127	0.517045	8.024 	17.046
# 3  	15.9997	0.510105	8.024 	17.046
# 4  	15.9702	0.535682	8.024 	17.05
# 5  	15.9499	0.823847	8.024 	17.05
# 6  	15.8371	1.22527 	8.024 	17.05
# 7  	15.8738	1.05671 	8.024 	17.054
# 8  	15.9097	0.943568	8.024 	17.058
# 9  	15.8362	1.236   	8.024 	17.058
# 10 	15.7932	1.32385 	8.024 	17.062
# 11 	15.7607	1.47996 	8.024 	18.054
# 12 	15.6314	1.71047 	8.024 	18.06
# 13 	15.645 	1.66025 	8.024 	18.06
# 14 	15.6089	1.70778 	8.024 	17.058
# 15 	15.6383	1.67016 	8.024 	17.058
# 16 	15.5848	1.91954 	8.024 	20.044
# 17 	15.4314	2.24525 	8.024 	20.03
# 18 	15.2515	2.54213 	8.024 	24.032
# 19 	14.9592	2.78667 	8.024 	24.032
# 20 	14.426 	3.17806 	8.024 	20.03
# 21 	14.0193	3.52196 	8.024 	24.034
# 22 	13.1464	3.767   	8.024 	20.034
# 23 	12.9469	3.97732 	8.024 	28.044
# 24 	13.001 	3.9765  	4.032 	28.044
# 25 	12.8442	4.14264 	4.032 	28.044
# ...
