# %%
# %matplotlib inline
import random
import numpy
from deap import tools
from app.problem import pset, creator, toolbox
from app.ourMods import draw, eaNigel

# %%
pop = toolbox.population(n=100)
hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("median", numpy.median)
stats.register("std", numpy.std)
stats.register("min", numpy.min)
pop, logbook = eaNigel(pop, toolbox, 40, 400, stats, halloffame=hof)
print(hof[0].fitness.values[0])
draw(hof[0])
# Out:
# gen	nevals	median 	std    	min
# 0  	100   	544.033	792139 	225.229
# 1  	100   	270.229	1415.45	225.229
# 2  	100   	270.229	1152.39	220.771
# 3  	100   	270.229	320468 	220.771
# 4  	100   	270.229	409.416	220.771
# 5  	100   	270.229	404938 	220.771
# 6  	100   	270.229	211949 	211.711
# 7  	100   	270.229	1757.59	203.14
# 8  	100   	270.229	145744 	203.14
# 9  	100   	270.229	1047.81	203.14
# 10 	100   	270.229	114025 	203.14
# 11 	100   	270.229	213848 	203.14
# 12 	100   	270.229	410458 	210.03
# 13 	100   	270.229	2986.93	225.229
# 14 	100   	265.229	830.31 	132.927
# 15 	100   	266.979	91913.7	132.927
# 16 	100   	270.229	129292 	132.927
# 17 	100   	270.229	113976 	132.927
# 18 	100   	235.229	2853.61	132.927
# 19 	100   	225.229	155153 	132.927
# 20 	100   	225.229	404367 	132.927
# 21 	100   	225.229	1983.25	132.927
# 22 	100   	225.229	1438.55	132.927
# 23 	100   	225.229	278.686	132.927
# 24 	100   	225.229	216478 	132.927
# 25 	100   	225.229	2699.62	132.927
# 26 	100   	225.229	114012 	132.927
# 27 	100   	225.229	360476 	132.927
# 28 	100   	225.229	113996 	132.927
# 29 	100   	225.229	1229.6 	132.927
# 30 	100   	225.229	299949 	132.927
# 31 	100   	225.229	299977 	132.927
# 32 	100   	214.472	90792.1	132.927
# 33 	100   	225.229	145681 	132.927
# 34 	100   	225.229	113943 	132.927
# 35 	100   	225.229	189213 	132.927
# 36 	100   	225.229	414937 	132.927
# 37 	100   	181.55 	688.241	132.927
# 38 	100   	218    	848.296	132.927
# 39 	100   	225.229	169840 	132.927
# 40 	100   	224.553	767.579	132.927
# 41 	100   	225.68 	192859 	132.927
# 42 	100   	228.581	4178.29	132.927
# 43 	100   	255.229	180062 	132.927
# 44 	100   	239.179	208443 	132.927
# 45 	100   	225.229	574088 	132.927
# 46 	100   	225.229	2223.73	132.927
# 47 	100   	225.229	183799 	132.927
# 48 	100   	225.229	3204.03	132.927
# 49 	100   	225.229	1020.86	132.927
# 50 	100   	225.229	693.541	132.927
# 51 	100   	225.229	145715 	132.927
# 52 	100   	225.229	1422.57	132.927
# 53 	100   	210.771	3205.04	132.927
# 54 	100   	225.229	157528 	132.927
# 55 	100   	210.771	1430.63	132.927
# 56 	100   	210.771	114309 	132.927
# 57 	100   	197.998	2452.56	132.927
# 58 	100   	223.889	92488.1	132.927
# 59 	100   	225.229	360450 	132.927
# 60 	100   	218    	752.89 	132.927
# 61 	100   	210.771	113980 	132.927
# 62 	100   	225.229	611.293	132.927
# 63 	100   	225.229	12538.8	132.927
# 64 	100   	225.229	145622 	132.927
# 65 	100   	225.229	1061.07	132.927
# 66 	100   	216.034	1090.14	132.927
# 67 	100   	222.93 	113998 	132.927
# 68 	100   	225.229	744.086	132.927
# 69 	100   	225.229	84765.7	132.927
# 70 	100   	225.229	4104.25	136.599
# 71 	100   	225.229	800.408	136.599
# 72 	100   	270.229	73605.3	136.599
# 73 	100   	255.229	343110 	136.599
# 74 	100   	270.229	1335.4 	40
# 40.0
