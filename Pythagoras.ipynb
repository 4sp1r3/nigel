# %%
# %matplotlib inline
import random
import numpy
from deap import tools
from app.problem import pset, creator, toolbox
from app.ourMods import draw, eaNigel

# %%
pop = toolbox.population(n=100)
hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("median", numpy.median)
stats.register("std", numpy.std)
stats.register("min", numpy.min)
pop, logbook = eaNigel(pop, toolbox, 40, 400, stats, halloffame=hof)
print(hof[0].fitness.values[0])
draw(hof[0])
# Out:
# gen	nevals	median 	std        	min
# 0  	100   	599.501	1.00232e+06	216.161
# 1  	100   	298.161	11334.7    	216.161
# 2  	100   	234.137	3335.53    	194.235
# 3  	100   	216.161	108143     	194.235
# 4  	100   	216.161	292901     	216.161
# 5  	100   	216.161	995.656    	194.057
# 6  	100   	216.161	152258     	194.057
# 7  	100   	216.161	153279     	194.057
# 8  	100   	216.161	323779     	194.057
# 9  	100   	216.161	1227.09    	194.057
# 10 	100   	216.161	273943     	194.057
# 11 	100   	216.161	90405.6    	173.588
# 12 	100   	216.161	399524     	173.588
# 13 	100   	216.161	4609.28    	178.06
# 14 	100   	216.161	856.325    	178.06
# 15 	100   	216.161	486861     	147.442
# 16 	100   	216.161	1155.98    	147.442
# 17 	100   	216.161	188478     	147.442
# 18 	100   	216.161	864.936    	147.442
# 19 	100   	216.161	165593     	147.442
# 20 	100   	216.161	214275     	147.442
# 21 	100   	216.161	331633     	147.442
# 22 	100   	216.161	1041.49    	147.442
# ...
