# %%
# %matplotlib inline
from custom import draw
from pythagoras import *
set_creator()

# %%
pop, logbook = run(get_toolbox(get_pset()))
# Out:
# gen	nevals	avg   	std   	max        	min
# 0  	100   	105293	490811	4.23158e+06	112.698
# 1  	95    	156204	571340	4.20959e+06	112.698
# 2  	95    	150496	527477	3.52185e+06	112.698
# 3  	92    	202468	655896	4.46485e+06	112.698
# 4  	95    	216714	666215	4.46485e+06	162.296
# 5  	90    	269863	805107	4.46485e+06	211.904
# 6  	92    	249225	712154	4.71076e+06	222.451
# 7  	94    	305412	890293	4.70844e+06	222.451
# 8  	95    	351981	1.05732e+06	4.90544e+06	214.204
# 9  	86    	337916	983870     	4.90806e+06	122.555
# 10 	94    	414595	1.08769e+06	5.00001e+06	189.206
# 11 	91    	326618	978550     	5.00001e+06	183.219
# 12 	76    	358940	999645     	5.00001e+06	183.219
# 13 	93    	425796	1.08671e+06	5.00001e+06	215.415
# 14 	90    	433943	1.08538e+06	5.00001e+06	145.074
# 15 	90    	475636	1.1571e+06 	5.00001e+06	107.372
# 16 	90    	467917	1.18937e+06	5.00002e+06	107.372
# 17 	87    	456538	1.1779e+06 	5.00002e+06	112.698
# 18 	88    	477131	1.19828e+06	5.00002e+06	133.466
# ...

# %%
for i in pop[:20]:
    print(i.fitness)
# Out:
# (21.82213339004329,)
# (34.0,)
# (35.0,)
# (47.0,)
# (525.5005884908703,)
# (214.4540679370402,)
# (227.95754499919735,)
# (246.33910705224554,)
# (246.33910705224554,)
# (246.33910705224554,)
# (246.33910705224554,)
# (460.3699836816685,)
# (262.33910705224554,)
# (262.33910705224554,)
# (262.33910705224554,)
# (264.33910705224554,)
# (744.3391070522457,)
# (742.3391070522457,)
# (268.6867661314785,)
# (208.6257657708291,)

# %%
print(pop[0])
draw(pop[0])
# Out:
# sqrt(sqrt(plus(square(minus(minus(minus(gety(P), square(getx(P))), square(sqrt(square(gety(P))))), getx(P))), getx(P))))
