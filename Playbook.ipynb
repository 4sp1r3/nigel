# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx

# %%
from deap.gp import PrimitiveTree
from custom import draw, ourGrow
from pythagoras import set_creator, get_pset, get_toolbox
set_creator()
pset = get_pset()

# %%
ind = PrimitiveTree(ourGrow(pset, 20, float, 0.001))
print(ind.height, ind)
draw(ind)
# Out:
# 15 sqrt(plus(sqrt(getx(P)), plus(sqrt(minus(sqrt(plus(plus(minus(plus(plus(gety(P), sqrt(getx(P))), minus(gety(P), plus(plus(plus(gety(P), getx(P)), square(getx(P))), gety(P)))), sqrt(getx(P))), sqrt(sqrt(gety(P)))), getx(P))), square(getx(P)))), square(getx(P)))))
