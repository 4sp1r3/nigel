# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
from pythagoras import *

# %%
set_creator()
pset = get_pset()
toolbox = get_toolbox(pset)

# %%
pop = toolbox.population(n=2)

# %%
print("Score\tProgram")
for i in pop:
    print("%s\t%s" % (int(toolbox.evaluate(i)[0]), str(i)))
# Out:
# Score	Program
# 267	plus(getx(in_point), plus(plus(plus(2, 2), gety(in_point)), 8))
# 3640	plus(plus(plus(square(7), square(4)), 1), minus(square(plus(3, 8)), 0))

# %%
for ind in pop:
    draw(ind)
