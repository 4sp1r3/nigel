# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
from custom import *

# %%
from pythagoras import *
set_creator()
pset = get_pset()
toolbox = get_toolbox(pset)

# %%
# regenerate the population
pop = toolbox.population(n=3)

# %%
# list the score and program of the population
print("Score\tHeight\tProgram")
for i in pop:
    print("%s\t%s\t%s" % (int(toolbox.evaluate(i)[0]), i.height+1, str(i)))
    
# graph them all
for ind in pop:
    draw(ind)
# Out:
# Score	Height	Program
# 534	4	plus(sqrt(gety(P)), minus(getx(P), getx(P)))
# 223	2	getx(P)
# 1061070	5	square(plus(square(getx(P)), sqrt(getx(P))))
