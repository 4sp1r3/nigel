# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
from app import fiveparity
from app.ourMods import draw

# %%
pop, stats, hof = fiveparity.main()
# Out:
# gen	nevals	avg  	std     	min	max
# 0  	300   	16   	0.258199	14 	18
# 1  	300   	15.98	0.3646  	12 	18
# 2  	300   	15.9967	0.412297	12 	18
# 3  	300   	15.9667	0.521749	12 	18
# 4  	300   	15.9567	0.722119	12 	20
# 5  	300   	15.92  	0.707295	12 	18
# 6  	300   	15.8433	1.06087 	8  	17
# 7  	300   	15.88  	1.00942 	8  	18
# 8  	300   	15.85  	1.19478 	8  	20
# 9  	300   	15.7767	1.47426 	8  	18
# 10 	300   	15.8367	1.67232 	4  	24
# 11 	300   	15.9467	1.27691 	8  	24
# 12 	300   	15.8533	1.61198 	8  	24
# 13 	300   	15.7   	1.43178 	8  	20
# 14 	300   	15.7967	1.41727 	8  	20
# 15 	300   	15.7167	1.45478 	8  	20
# 16 	300   	15.7967	1.18406 	8  	18
# 17 	300   	15.71  	1.43268 	8  	18
# 18 	300   	15.5267	2.09824 	6  	21
# 19 	300   	15.3433	2.52695 	6  	22
# 20 	300   	14.9633	2.83349 	4  	22
# 21 	300   	14.8267	2.73068 	6  	22
# 22 	300   	14.7833	2.88035 	6  	20
# 23 	300   	14.9633	2.77645 	6  	22
# 24 	300   	14.7367	2.80487 	6  	20
# 25 	300   	14.6067	3.1515  	4  	26
# 26 	300   	13.9   	3.7081  	4  	20
# 27 	300   	13.6267	4.00923 	4  	24
# 28 	300   	13.0867	4.60281 	4  	24
# 29 	300   	12.2667	4.66429 	4  	24
# 30 	300   	12.3333	4.74646 	0  	26

# %%
ind = hof[0]
print(ind.fitness)
draw(ind)
# Out:
# (0.0,)

# %%
ind = hof[1]
print(ind.fitness)
draw(ind)
# Out:
# (2.0,)
