# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
from app import fiveparity
from app.ourMods import draw

# %%
pop, stats, hof = fiveparity.main()
# Out:
# gen	nevals	avg    	std     	min   	max
# 0  	300   	16.0126	0.513602	14.017	18.029
# 1  	300   	15.9744	0.536278	14.017	18.031
# 2  	300   	15.9546	0.540323	14.017	18.037
# 3  	300   	16.0026	0.513421	14.017	18.031
# 4  	300   	15.9876	0.528289	14.017	17.051
# 5  	300   	15.9797	0.548433	14.035	18.039
# 6  	300   	15.9939	0.518524	14.025	18.033
# 7  	300   	15.9822	0.524625	14.027	18.045
# 8  	300   	15.9355	0.542203	13.067	17.099
# 9  	300   	15.9659	0.607276	14.085	18.015
# 10 	300   	15.9817	0.543831	14.085	18.029
# 11 	300   	15.9677	0.644597	14.041	18.035
# 12 	300   	15.9851	0.642935	14.023	18.057
# 13 	300   	15.9886	0.700426	14.027	18.057
# 14 	300   	16.03  	0.687403	14.033	18.057
# 15 	300   	15.957 	0.693117	14.023	19.049
# 16 	300   	15.9955	0.736868	14.037	19.055
# 17 	300   	15.9152	0.706816	14.021	19.049
# 18 	300   	15.9658	0.710626	13.047	20.051
# 19 	300   	15.9127	0.698544	14.021	19.051
# 20 	300   	15.8716	0.769436	13.051	19.051
# ...

# %%
ind = hof[0]
print(ind.fitness)
draw(ind)
# Out:
# (9.219,)

# %%
ind = hof[1]
print(ind.fitness)
draw(ind)
# Out:
# (10.203,)
