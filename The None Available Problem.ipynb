# %% [markdown]
# _This is a simple program to demonstrate a teething issue we are having with the correct structuring of the primitive set._
#
# 1. First we set up the deap program environment, then
# 1. declare a primitive set that works and run it, then
# 1. redefine that primitive set to remove the terminals and re-run it, thus exposing the error.

# %%
# %load_ext autoreload

# %%
import random
import numpy
import math

from deap import gp
from deap import creator
from deap import base
from deap import tools
from deap import algorithms

# %%
PLANE_SIZE = 8
POPULATION_SIZE = 100


class Point(object):
    """
    A point on a plane
    """
    def __init__(self, x, y):
        """
        x and y is a black point on a white photo
        """
        self.x = x
        self.y = y

    def __repr__(self):
        return "<%s, %s>" % (self.x, self.y)

    def getx(self):
        return self.x

    def gety(self):
        return self.y

    @staticmethod
    def distance(this, that):
        """Return the distance between the point on this and the point provided"""
        return math.sqrt((this.x - that.x) ** 2 + (this.y - that.y) ** 2)


class RandomPoint(Point):
    def __init__(self):
        super(RandomPoint, self).__init__(*[random.randrange(0, PLANE_SIZE) for _ in range(2)])


A_RANDOMPOINTS = [RandomPoint() for _ in range(10)]


# A smaller score (distance) is better
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))

# Every individual is a tree of operations (plus a Fitness class)
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)


def get_toolbox(pset):
    """
    :return: a configured toolbox
    """
    toolbox = base.Toolbox()
    toolbox.register("expr", gp.genGrow, pset, min_=1, max_=50)
    toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("compile", gp.compile, pset=pset)

    def eval_func(individual):
        """
        Apply the program to pairs of triangles in the sample set.  Tally up the differences
        between the output and the goal.
        """
        # print(individual)
        program = toolbox.compile(expr=individual)
        score = 0
        for point_in in A_RANDOMPOINTS:
            point_out = program(point_in)
            diff = Point.distance(point_in, point_out)
            score += diff
        return score,

    toolbox.register("evaluate", eval_func)
    toolbox.register("select", tools.selBest)
    toolbox.register("mate", gp.cxOnePoint)
    toolbox.register("expr_mut", gp.genGrow, min_=0, max_=5)
    toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)
    return toolbox


def run(toolbox):
    pop = toolbox.population(n=POPULATION_SIZE)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", numpy.mean)
    stats.register("std", numpy.std)
    stats.register("max", numpy.max)
    stats.register("min", numpy.min)
    return algorithms.eaSimple(pop, toolbox, 0.5, 0.2, 10, stats, halloffame=hof)


def main():
    pop, logbook = run(get_toolbox(get_pset()))
    for i in sorted(pop, key=lambda i: i.fitness.values[0], reverse=True):
        print(int(i.fitness.values[0]), i)

# %% [markdown]
# ### This primitive set works...

# %%
def get_pset():
    """
    :return: a typed set of primitive operations
    """
    pset = gp.PrimitiveSetTyped(
        "DAIN",
        [Point],
        Point
    )

    # get coordinates of a point
    pset.addPrimitive(Point.getx, [Point], int, name='getx')
    pset.addPrimitive(Point.gety, [Point], int, name='gety')

    # create a point
    pset.addPrimitive(Point, [int, int], Point, name='new_point')

    # create a terminal for every int
    pset.addEphemeralConstant("Rint", lambda: random.randint(0, PLANE_SIZE), int)

    # give the input args more meaningful names
    pset.renameArguments(ARG0='in_point')
    return pset

# %%
main()
# Out:
# gen	nevals	avg    	std    	max   	min
# 0  	100   	36.6923	13.2213	66.832	0
# 1  	52    	34.4631	15.0736	71.6567	0
# 2  	54    	34.0232	16.0816	71.6567	0
# 3  	63    	34.2702	16.1582	69.0133	0
# 4  	62    	35.3787	15.4741	69.0133	0
# 5  	63    	36.3848	15.6943	69.0133	0
# 6  	60    	36.4968	15.1506	69.0133	0
# 7  	53    	36.9276	15.1722	69.0133	0
# 8  	66    	36.8312	15.2251	69.0133	0
# 9  	59    	35.656 	15.5763	69.0133	0
# 10 	71    	35.598 	15.2367	69.0133	0
# 69 new_point(8, 8)
# 69 new_point(getx(new_point(8, 8)), 8)
# 64 new_point(7, gety(new_point(gety(new_point(6, gety(new_point(gety(new_point(2, gety(in_point))), gety(new_point(7, getx(in_point))))))), getx(new_point(gety(new_point(4, getx(new_point(8, getx(in_point))))), 5)))))
# 61 new_point(8, getx(new_point(7, getx(in_point))))
# 61 new_point(getx(new_point(8, getx(new_point(gety(new_point(gety(new_point(5, 8)), getx(in_point))), gety(new_point(8, 2)))))), 7)
# 59 new_point(1, 7)
# 59 new_point(gety(in_point), 8)
# 57 new_point(0, gety(new_point(3, 6)))
# 57 new_point(gety(new_point(gety(in_point), getx(new_point(getx(new_point(0, 4)), getx(new_point(3, 6)))))), gety(new_point(8, 6)))
# 55 new_point(7, 7)
# 55 new_point(getx(new_point(7, getx(new_point(gety(new_point(8, 1)), 4)))), 7)
# 52 new_point(0, 5)
# 52 new_point(gety(new_point(2, 0)), 5)
# 50 new_point(4, 7)
# 50 new_point(0, getx(new_point(getx(in_point), gety(in_point))))
# 50 new_point(0, gety(new_point(gety(in_point), getx(in_point))))
# 47 new_point(2, 6)
# 47 new_point(2, gety(new_point(gety(new_point(getx(new_point(getx(new_point(7, 2)), gety(new_point(5, 5)))), 7)), gety(new_point(getx(in_point), getx(new_point(getx(new_point(getx(new_point(6, 3)), 5)), gety(in_point))))))))
# 47 new_point(getx(new_point(0, gety(in_point))), gety(new_point(gety(new_point(3, 7)), 4)))
# 47 new_point(0, 1)
# 47 new_point(0, 1)
# 46 new_point(7, gety(new_point(6, 0)))
# 46 new_point(7, getx(new_point(0, 0)))
# 46 new_point(gety(new_point(3, 7)), gety(new_point(gety(new_point(getx(new_point(getx(new_point(7, getx(new_point(getx(in_point), getx(in_point))))), 2)), gety(new_point(1, 1)))), 0)))
# 46 new_point(8, gety(new_point(0, 2)))
# 45 new_point(getx(new_point(gety(new_point(1, 1)), gety(in_point))), 0)
# 43 new_point(getx(new_point(1, getx(new_point(2, 2)))), gety(new_point(getx(in_point), getx(in_point))))
# 43 new_point(gety(new_point(gety(in_point), getx(in_point))), 7)
# 42 new_point(4, 6)
# 41 new_point(gety(new_point(getx(new_point(getx(new_point(8, 1)), 5)), getx(new_point(gety(new_point(getx(new_point(0, gety(new_point(1, 4)))), gety(new_point(gety(new_point(gety(in_point), 5)), gety(new_point(6, gety(in_point))))))), gety(new_point(getx(new_point(8, 6)), getx(in_point))))))), 6)
# 41 new_point(5, 6)
# 41 new_point(getx(new_point(5, getx(new_point(1, 8)))), gety(new_point(gety(in_point), gety(new_point(gety(in_point), 6)))))
# 41 new_point(gety(new_point(gety(new_point(7, 7)), 1)), 4)
# 40 new_point(gety(in_point), 0)
# 40 new_point(gety(in_point), 0)
# 40 new_point(8, gety(in_point))
# 39 new_point(3, 0)
# 38 new_point(getx(new_point(6, 6)), getx(new_point(getx(in_point), gety(in_point))))
# 38 new_point(6, getx(new_point(getx(new_point(gety(new_point(5, getx(in_point))), gety(in_point))), 2)))
# 38 new_point(2, getx(in_point))
# 38 new_point(2, getx(in_point))
# 37 new_point(gety(new_point(gety(in_point), gety(new_point(5, getx(new_point(3, getx(in_point))))))), 5)
# 37 new_point(gety(new_point(gety(new_point(gety(in_point), 1)), 3)), gety(new_point(6, gety(new_point(6, getx(new_point(5, 1)))))))
# 37 new_point(6, 1)
# 37 new_point(getx(new_point(gety(new_point(1, 6)), 2)), getx(new_point(getx(new_point(1, 7)), gety(new_point(8, 8)))))
# 35 new_point(3, getx(in_point))
# 35 new_point(3, gety(new_point(7, getx(in_point))))
# 35 new_point(gety(new_point(getx(in_point), 5)), getx(new_point(getx(in_point), getx(in_point))))
# 35 new_point(5, getx(new_point(gety(new_point(1, getx(in_point))), getx(new_point(2, 0)))))
# 35 new_point(gety(new_point(gety(in_point), 4)), 5)
# 34 new_point(getx(new_point(gety(new_point(3, 4)), 1)), getx(in_point))
# 34 new_point(getx(new_point(getx(new_point(getx(new_point(getx(new_point(4, gety(new_point(gety(new_point(getx(new_point(getx(in_point), 7)), 2)), gety(in_point))))), 7)), getx(new_point(gety(new_point(0, getx(in_point))), 7)))), getx(new_point(5, getx(new_point(gety(new_point(gety(in_point), gety(in_point))), gety(in_point))))))), getx(in_point))
# 34 new_point(getx(new_point(gety(new_point(4, getx(new_point(4, getx(new_point(5, 8)))))), 4)), getx(in_point))
# 34 new_point(getx(new_point(4, 1)), gety(new_point(getx(new_point(7, gety(new_point(7, gety(new_point(gety(in_point), gety(in_point))))))), getx(in_point))))
# 34 new_point(gety(in_point), 5)
# 34 new_point(gety(in_point), gety(new_point(4, 5)))
# 34 new_point(gety(in_point), 1)
# 34 new_point(gety(in_point), getx(new_point(getx(new_point(1, 5)), gety(new_point(1, 0)))))
# 34 new_point(1, getx(new_point(gety(in_point), 5)))
# 34 new_point(1, gety(in_point))
# 33 new_point(4, 1)
# 33 new_point(gety(new_point(2, 2)), 3)
# 33 new_point(getx(new_point(getx(new_point(6, 2)), 5)), 2)
# 33 new_point(3, getx(new_point(4, getx(new_point(gety(in_point), gety(new_point(4, getx(new_point(5, 6)))))))))
# 32 new_point(gety(in_point), getx(in_point))
# 32 new_point(gety(in_point), gety(new_point(getx(new_point(2, 1)), gety(new_point(gety(in_point), getx(new_point(getx(in_point), gety(in_point))))))))
# 32 new_point(gety(in_point), getx(in_point))
# 32 new_point(gety(new_point(gety(in_point), getx(new_point(gety(in_point), gety(in_point))))), getx(in_point))
# 31 new_point(getx(new_point(6, getx(new_point(3, getx(new_point(3, getx(new_point(getx(in_point), getx(new_point(7, 1)))))))))), getx(new_point(gety(new_point(gety(new_point(3, gety(new_point(gety(in_point), 6)))), 3)), 1)))
# 30 new_point(3, gety(new_point(gety(new_point(2, getx(new_point(getx(new_point(4, getx(new_point(5, 3)))), 3)))), 3)))
# 30 new_point(4, 4)
# 30 new_point(4, getx(new_point(2, 1)))
# 29 new_point(getx(new_point(gety(new_point(gety(in_point), gety(in_point))), 4)), 2)
# 28 new_point(getx(new_point(4, gety(new_point(3, gety(new_point(gety(in_point), 6)))))), gety(new_point(7, gety(new_point(6, 3)))))
# 28 new_point(4, getx(new_point(3, gety(in_point))))
# 28 new_point(gety(new_point(gety(new_point(getx(in_point), getx(in_point))), gety(new_point(1, gety(in_point))))), 3)
# 28 new_point(gety(in_point), 3)
# 28 new_point(2, getx(new_point(getx(new_point(gety(in_point), getx(new_point(6, 8)))), getx(in_point))))
# 27 new_point(5, gety(new_point(2, gety(new_point(getx(new_point(getx(in_point), gety(new_point(1, gety(new_point(1, gety(in_point))))))), 3)))))
# 27 new_point(getx(in_point), 0)
# 24 new_point(getx(new_point(4, getx(in_point))), getx(new_point(getx(new_point(gety(in_point), getx(in_point))), getx(new_point(0, 0)))))
# 24 new_point(4, getx(new_point(gety(in_point), getx(new_point(getx(new_point(getx(new_point(getx(in_point), 1)), gety(new_point(gety(new_point(getx(new_point(1, getx(in_point))), getx(new_point(getx(in_point), 4)))), 5)))), getx(in_point))))))
# 24 new_point(getx(new_point(6, 7)), gety(in_point))
# 23 new_point(gety(new_point(4, getx(in_point))), getx(in_point))
# 23 new_point(getx(in_point), gety(new_point(5, getx(new_point(getx(in_point), gety(in_point))))))
# 23 new_point(getx(new_point(getx(in_point), getx(new_point(8, 7)))), getx(in_point))
# 23 new_point(gety(in_point), gety(in_point))
# 23 new_point(gety(in_point), gety(in_point))
# 23 new_point(getx(in_point), 5)
# 22 new_point(getx(new_point(5, 6)), gety(in_point))
# 21 new_point(getx(new_point(gety(new_point(getx(in_point), getx(in_point))), 2)), gety(new_point(getx(new_point(6, getx(new_point(3, getx(new_point(gety(new_point(getx(new_point(2, 6)), getx(new_point(gety(in_point), 8)))), 1)))))), 1)))
# 13 new_point(getx(in_point), 3)
# 0 new_point(getx(in_point), gety(in_point))
# 0 in_point
# 0 new_point(getx(in_point), getx(new_point(gety(in_point), getx(in_point))))
# 0 in_point
# 0 new_point(gety(new_point(gety(new_point(gety(new_point(getx(new_point(getx(new_point(3, 4)), getx(new_point(6, 7)))), gety(new_point(getx(in_point), gety(new_point(0, 3)))))), getx(in_point))), getx(in_point))), gety(in_point))
# 0 in_point
# 0 in_point
# 0 in_point

# %% [markdown]
# ### Now the same primitive set but without the availability of the random integer (a Terminal):

# %%
def get_pset():
    """
    :return: a typed set of primitive operations
    """
    pset = gp.PrimitiveSetTyped(
        "DAIN",
        [Point],
        Point
    )

    # get coordinates of a point
    pset.addPrimitive(Point.getx, [Point], int, name='getx')
    pset.addPrimitive(Point.gety, [Point], int, name='gety')

    # create a point
    pset.addPrimitive(Point, [int, int], Point, name='new_point')

    # REMOVING THIS: create a terminal for every int
    # pset.addEphemeralConstant("Rint", lambda: random.randint(0, PLANE_SIZE), int)

    # give the input args more meaningful names
    pset.renameArguments(ARG0='in_point')
    return pset

# %% [markdown]
# ### This one doesn't work:
#
# Rerunning without the random ints creates this problem where it is not prepared to use the `getx` or `gety` (integer generating functions) to complete the tree.  I now believe this is because these functions would make the tree 2 layers deeper, whereas the `gengrow` function has been told to grow the tree only one more layer.
#
# When it says it has _nothing available_, it means **nothing of the required type and depth of nodes**.  In this case it wants an integer which needs just one layer.  But we took those away, the random int terminals, so we get this error:
#
# ```The gp.generate function tried to add a terminal of type '<class 'int'>', but there is none available.```

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/john/nigel/venv/lib/python3.4/random.py in choice(self, seq)
#     252         try:
# --> 253             i = self._randbelow(len(seq))
#     254         except ValueError:
#
# /home/john/nigel/venv/lib/python3.4/random.py in _randbelow(self, n, int, maxsize, type, Method, BuiltinMethod)
#     229             k = n.bit_length()  # don't use (n-1) here because n can be 1
# --> 230             r = getrandbits(k)          # 0 <= r < 2**k
#     231             while r >= n:
#
# ValueError: number of bits must be greater than zero
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/gp.py in generate(pset, min_, max_, condition, type_)
#     592             try:
# --> 593                 term = random.choice(pset.terminals[type_])
#     594             except IndexError:
#
# /home/john/nigel/venv/lib/python3.4/random.py in choice(self, seq)
#     254         except ValueError:
# --> 255             raise IndexError('Cannot choose from an empty sequence')
#     256         return seq[i]
#
# IndexError: Cannot choose from an empty sequence
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-58ca95c5b364> in <module>()
# ----> 1 main()
#
# <ipython-input-3-c3dd29006601> in main()
#      89
#      90 def main():
# ---> 91     pop, logbook = run(get_toolbox(get_pset()))
#      92     for i in sorted(pop, key=lambda i: i.fitness.values[0], reverse=True):
#      93         print(int(i.fitness.values[0]), i)
#
# <ipython-input-3-c3dd29006601> in run(toolbox)
#      78
#      79 def run(toolbox):
# ---> 80     pop = toolbox.population(n=POPULATION_SIZE)
#      81     hof = tools.HallOfFame(1)
#      82     stats = tools.Statistics(lambda ind: ind.fitness.values)
#
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/tools/init.py in initRepeat(container, func, n)
#      21     See the :ref:`list-of-floats` and :ref:`population` tutorials for more examples.
#      22     """
# ---> 23     return container(func() for _ in range(n))
#      24
#      25 def initIterate(container, generator):
#
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/tools/init.py in <genexpr>(.0)
#      21     See the :ref:`list-of-floats` and :ref:`population` tutorials for more examples.
#      22     """
# ---> 23     return container(func() for _ in range(n))
#      24
#      25 def initIterate(container, generator):
#
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/tools/init.py in initIterate(container, generator)
#      47     more examples.
#      48     """
# ---> 49     return container(generator())
#      50
#      51 def initCycle(container, seq_func, n=1):
#
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/gp.py in genGrow(pset, min_, max_, type_)
#     538         return depth == height or \
#     539                (depth >= min_ and random.random() < pset.terminalRatio)
# --> 540     return generate(pset, min_, max_, condition, type_)
#     541
#     542 def genHalfAndHalf(pset, min_, max_, type_=None):
#
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/gp.py in generate(pset, min_, max_, condition, type_)
#     596                 raise IndexError("The gp.generate function tried to add "\
#     597                                   "a terminal of type '%s', but there is "\
# --> 598                                   "none available." % (type_,)).with_traceback(traceback)
#     599             if isclass(term):
#     600                 term = term()
#
# /home/john/nigel/venv/lib/python3.4/site-packages/deap/gp.py in generate(pset, min_, max_, condition, type_)
#     591         if condition(height, depth):
#     592             try:
# --> 593                 term = random.choice(pset.terminals[type_])
#     594             except IndexError:
#     595                 _, _, traceback = sys.exc_info()
#
# /home/john/nigel/venv/lib/python3.4/random.py in choice(self, seq)
#     253             i = self._randbelow(len(seq))
#     254         except ValueError:
# --> 255             raise IndexError('Cannot choose from an empty sequence')
#     256         return seq[i]
#     257
#
# IndexError: The gp.generate function tried to add a terminal of type '<class 'int'>', but there is none available.
