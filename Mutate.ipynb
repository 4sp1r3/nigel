# %%
# %matplotlib inline
from app.problem import pset, creator, toolbox
from app.ourMods import draw

# %%
pop = toolbox.population(n=2)

# %%
for ind in pop:
    draw(ind)
    mutt = toolbox.mutate(ind)[0]
    draw(mutt)
